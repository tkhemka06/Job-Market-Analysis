# %% [markdown]
# ### Project Main

# %% [markdown]
# #### Required Libraries

# %% [markdown]
# ##### DESCRIPTION
# This project is designed to scrape job postings from various sources, including Indeed, LinkedIn, ZipRecruiter, Glassdoor, Google and multiple such job portals available on the internet. The application provides a streamlined interface for retrieving job data based on user-defined criteria such as search terms, location, and time of posting as well as the user being able to quickly apply to the given job. It can only  be used for country of USA for now.
#
# ##### Team Members:
# Jiya Aggarwal - jagarwal@andrew.cmu.edu
# Summer Lee - summerle@andrew.cmu.edu
# Tanisha Khemka - tkhemka@andrew.cmu.edu
# Aditya Sannabhadti - asannabh@andrew.cmu.edu

# %%
# Install required packages
# !pip install -U python-jobspy requests beautifulsoup4 flask python-dotenv googlemaps crochet flask_ngrok flask_cors
# !pip install -U flask
# !pip install -U pyngrok
# !pip install flask-cors
# !pip install Flask-Mail
# !pip install pyngrok
import os
print(os.getcwd())


# Import necessary modules
import csv
import os
import sys
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import flask
from flask import Flask, render_template, request, jsonify
from flask_ngrok import run_with_ngrok
from dotenv import load_dotenv
import googlemaps
from crochet import setup, wait_for
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email.mime.application import MIMEApplication
from email.utils import COMMASPACE, formatdate
from email import encoders
from jobspy import scrape_jobs
from google.colab import files
import getpass
import os
import threading
from flask import Flask
from pyngrok import ngrok, conf
from flask_mail import Mail, Message

# Load environment variables
load_dotenv()

from google.colab import drive
drive.mount('/content/drive')

import shutil
import os

source_dir = '/content/drive/MyDrive/Python_Proj'
destination_dir = '/content/'

# Ensure the destination directory exists
os.makedirs(destination_dir, exist_ok=True)

# Copy the contents of the source directory to the destination
shutil.copytree(source_dir, destination_dir, dirs_exist_ok=True)
# Out:
# Requirement already satisfied: python-jobspy in /usr/local/lib/python3.10/dist-packages (1.1.76)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: googlemaps in /usr/local/lib/python3.10/dist-packages (4.10.0)
# Requirement already satisfied: crochet in /usr/local/lib/python3.10/dist-packages (2.1.1)
# Requirement already satisfied: flask_ngrok in /usr/local/lib/python3.10/dist-packages (0.0.25)
# Requirement already satisfied: flask_cors in /usr/local/lib/python3.10/dist-packages (5.0.0)
# Requirement already satisfied: NUMPY==1.26.3 in /usr/local/lib/python3.10/dist-packages (from python-jobspy) (1.26.3)
# Requirement already satisfied: markdownify<0.14.0,>=0.13.1 in /usr/local/lib/python3.10/dist-packages (from python-jobspy) (0.13.1)
# Requirement already satisfied: pandas<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from python-jobspy) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from python-jobspy) (2.10.2)
# Requirement already satisfied: regex<2025.0.0,>=2024.4.28 in /usr/local/lib/python3.10/dist-packages (from python-jobspy) (2024.9.11)
# Requirement already satisfied: tls-client<2.0.0,>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from python-jobspy) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.10/dist-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.10/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.10/dist-packages (from flask) (1.9.0)
# Requirement already satisfied: Twisted>=16.0 in /usr/local/lib/python3.10/dist-packages (from crochet) (24.11.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from crochet) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# Requirement already satisfied: six<2,>=1.15 in /usr/local/lib/python3.10/dist-packages (from markdownify<0.14.0,>=0.13.1->python-jobspy) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.1.0->python-jobspy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.1.0->python-jobspy) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.1.0->python-jobspy) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.3.0->python-jobspy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.3.0->python-jobspy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.3.0->python-jobspy) (4.12.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from Twisted>=16.0->crochet) (24.2.0)
# Requirement already satisfied: automat>=24.8.0 in /usr/local/lib/python3.10/dist-packages (from Twisted>=16.0->crochet) (24.8.1)
# Requirement already satisfied: constantly>=15.1 in /usr/local/lib/python3.10/dist-packages (from Twisted>=16.0->crochet) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in /usr/local/lib/python3.10/dist-packages (from Twisted>=16.0->crochet) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in /usr/local/lib/python3.10/dist-packages (from Twisted>=16.0->crochet) (24.7.2)
# Requirement already satisfied: zope-interface>=5 in /usr/local/lib/python3.10/dist-packages (from Twisted>=16.0->crochet) (7.2)
# Requirement already satisfied: setuptools>=61.0 in /usr/local/lib/python3.10/dist-packages (from incremental>=24.7.0->Twisted>=16.0->crochet) (75.1.0)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from incremental>=24.7.0->Twisted>=16.0->crochet) (2.2.1)
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.10/dist-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.10/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.10/dist-packages (from flask) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.10/dist-packages (7.2.1)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: flask-cors in /usr/local/lib/python3.10/dist-packages (5.0.0)
# Requirement already satisfied: Flask>=0.9 in /usr/local/lib/python3.10/dist-packages (from flask-cors) (3.1.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.9->flask-cors) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.9->flask-cors) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.9->flask-cors) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.9->flask-cors) (8.1.7)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.9->flask-cors) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.1.2->Flask>=0.9->flask-cors) (3.0.2)
# Requirement already satisfied: Flask-Mail in /usr/local/lib/python3.10/dist-packages (0.10.0)
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (from Flask-Mail) (3.1.0)
# Requirement already satisfied: blinker in /usr/local/lib/python3.10/dist-packages (from Flask-Mail) (1.9.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.10/dist-packages (from flask->Flask-Mail) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from flask->Flask-Mail) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.10/dist-packages (from flask->Flask-Mail) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from flask->Flask-Mail) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.1.2->flask->Flask-Mail) (3.0.2)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.10/dist-packages (7.2.1)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.2)
# /content
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/'

# %% [markdown]
# # WebScraping APIS
# ## Scraping LinkedIN, ZipRecruiter, Google, Glassdoor, Indeed

# %% [markdown]
# ### JobSpyAPI

# %%
def JobSpyAPI(s_t,loc,h_o,c_i):
  jobs = scrape_jobs(
      site_name=["indeed", "linkedin", "zip_recruiter", "glassdoor", "google"],
      search_term=s_t,
      google_search_term= s_t+"jobs near"+ loc+"since"+h_o,
      location=loc,
      results_wanted=10,
      hours_old = h_o,
      country_indeed=c_i,
  )
  return jobs
# Out:
# 2024-12-06 14:54:49,365 - INFO - JobSpy:Indeed - search page: 1 / 1
# 2024-12-06 14:54:49,366 - INFO - JobSpy:LinkedIn - search page: 1 / 1
# 2024-12-06 14:54:49,539 - INFO - JobSpy:ZipRecruiter - search page: 1 / 1
# 2024-12-06 14:54:50,380 - INFO - JobSpy:Google - finished scraping
# 2024-12-06 14:54:50,387 - INFO - JobSpy:ZipRecruiter - finished scraping
# 2024-12-06 14:54:50,649 - INFO - JobSpy:Indeed - finished scraping
# 2024-12-06 14:54:51,110 - INFO - JobSpy:Glassdoor - search page: 1 / 1
# 2024-12-06 14:54:52,296 - INFO - JobSpy:Glassdoor - finished scraping
# 2024-12-06 14:55:20,083 - ERROR - JobSpy:LinkedIn - LinkedIn: HTTPSConnectionPool(host='www.linkedin.com', port=443): Max retries exceeded with url: /jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=Intern&location=USA&distance=50&pageNum=0&start=0&f_TPR=r259200 (Caused by ResponseError('too many 429 error responses'))
# 2024-12-06 14:55:20,084 - INFO - JobSpy:Linkedin - finished scraping
#                              id           site  \
# 0              gd-1009554694594      glassdoor
# 1              gd-1009554236825      glassdoor
# 2              gd-1009554647193      glassdoor
# 3              gd-1009553261956      glassdoor
# 4              gd-1009553261959      glassdoor
# 5              gd-1009553263069      glassdoor
# 6              gd-1009551127191      glassdoor
# 7              gd-1009551324920      glassdoor
# 8              gd-1009551668222      glassdoor
# 9              gd-1009551234862      glassdoor
# 10  go-I59MAylIo1l4W-j9AAAAAA==         google
# 11  go-yplMSWAfIStnFLnPAAAAAA==         google
# 12  go-4L6Mg0MjAVj7o4r3AAAAAA==         google
# 13  go-H-2d2kePYypO4GgXAAAAAA==         google
# 14  go-rPDA8zb75fK6n6oZAAAAAA==         google
# 15  go-57wpZdeAWb0f1SRTAAAAAA==         google
# 16  go-o5tfxgjyNVsMkc22AAAAAA==         google
# 17  go-rwyuQrfpnk0ZCtIVAAAAAA==         google
# 18  go-yZdqoxNh-S7cnDTLAAAAAA==         google
# 19  go-2EUHlgzptirDALe3AAAAAA==         google
# 20          in-c21ddc0cc1f259e4         indeed
# 21          in-3fc2cf169f113291         indeed
# 22          in-7530f1e1f0f8a677         indeed
# 23          in-5b12619e12e665aa         indeed
# 24          in-f2b0f40a7dc25675         indeed
# 25          in-cc75999c3cbf5e48         indeed
# 26          in-24e1d67e555733e2         indeed
# 27          in-25eaf0b1f520e4c6         indeed
# 28          in-5bf0862be10b2161         indeed
# 29          in-50b30ba979a53222         indeed
# 30    zr-fG8kzdjJUmfOj6FOA_8QoQ  zip_recruiter
# 31    zr-skAsp5YnIeD4wGeV9RoGJg  zip_recruiter
# 32    zr-5mJ1wW7ycicTiblseqXKNw  zip_recruiter
# 33    zr-4dusmuTheEI47zlsd4rLbw  zip_recruiter
# 34    zr-YKORXyOVJsvlS5rhW1rBZg  zip_recruiter
# 35    zr-o20GBGtb5qqohhL9f8qxdA  zip_recruiter
# 36    zr-jcEWK6RV7vnn1hf_j1cy3A  zip_recruiter
# 37    zr-iCwzQSAbiwAQkxKLt79G7Q  zip_recruiter
# 38    zr-Q0uS_UvQNUXh_GCEbu0CYQ  zip_recruiter
# 39    zr-ziJkuzBTHZJohxysLQTjzA  zip_recruiter
#
#                                               job_url  \
# 0   https://www.glassdoor.com/job-listing/j?jl=100...
# 1   https://www.glassdoor.com/job-listing/j?jl=100...
# 2   https://www.glassdoor.com/job-listing/j?jl=100...
# 3   https://www.glassdoor.com/job-listing/j?jl=100...
# 4   https://www.glassdoor.com/job-listing/j?jl=100...
# 5   https://www.glassdoor.com/job-listing/j?jl=100...
# 6   https://www.glassdoor.com/job-listing/j?jl=100...
# 7   https://www.glassdoor.com/job-listing/j?jl=100...
# 8   https://www.glassdoor.com/job-listing/j?jl=100...
# 9   https://www.glassdoor.com/job-listing/j?jl=100...
# 10  https://www.linkedin.com/jobs/view/software-en...
# 11  https://www.internsgrab.net/72-and-sunny-inter...
# 12  https://www.linkedin.com/jobs/view/prot%C3%A9g...
# 13  https://www.entertainmentcareers.net/usa-baseb...
# 14  https://www.linkedin.com/jobs/view/summer-2025...
# 15  https://www.recruit.net/job/planning-engineer-...
# 16  https://www.linkedin.com/jobs/view/corporate-f...
# 17  https://apply.slb.com/careers/job/563499719199...
# 18  https://www.coolworks.com/hawthorne-valley/hig...
# 19  https://apply.slb.com/careers/job/563499719315...
# 20  https://www.indeed.com/viewjob?jk=c21ddc0cc1f2...
# 21  https://www.indeed.com/viewjob?jk=3fc2cf169f11...
# 22  https://www.indeed.com/viewjob?jk=7530f1e1f0f8...
# 23  https://www.indeed.com/viewjob?jk=5b12619e12e6...
# 24  https://www.indeed.com/viewjob?jk=f2b0f40a7dc2...
# 25  https://www.indeed.com/viewjob?jk=cc75999c3cbf...
# 26  https://www.indeed.com/viewjob?jk=24e1d67e5557...
# 27  https://www.indeed.com/viewjob?jk=25eaf0b1f520...
# 28  https://www.indeed.com/viewjob?jk=5bf0862be10b...
# 29  https://www.indeed.com/viewjob?jk=50b30ba979a5...
# 30  https://www.ziprecruiter.com/jobs//j?lvk=fG8kz...
# 31  https://www.ziprecruiter.com/jobs//j?lvk=skAsp...
# 32  https://www.ziprecruiter.com/jobs//j?lvk=5mJ1w...
# 33  https://www.ziprecruiter.com/jobs//j?lvk=4dusm...
# 34  https://www.ziprecruiter.com/jobs//j?lvk=YKORX...
# 35  https://www.ziprecruiter.com/jobs//j?lvk=o20GB...
# 36  https://www.ziprecruiter.com/jobs//j?lvk=jcEWK...
# 37  https://www.ziprecruiter.com/jobs//j?lvk=iCwzQ...
# 38  https://www.ziprecruiter.com/jobs//j?lvk=Q0uS_...
# 39  https://www.ziprecruiter.com/jobs//j?lvk=ziJku...
#
#                                        job_url_direct  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  https://jobs.allcraftjobs.com/Kiewit_Craft/job...
# 21  http://www.indeed.com/job/undergraduate-summer...
# 22           https://www.hashicorp.com/career/6389037
# 23  https://click.jobsplice.com/redirect/MzAyMzQwM...
# 24  https://jobs.spectrum.com/job/-/-/4673/7408526...
# 25  https://careers.universityhealth.com/job/-/-/4...
# 26  https://jobs.avalonbay.com/job/-/-/125/7407580...
# 27  https://careers.hcsc.com/job/-/-/43046/7405496...
# 28     https://jobs.intel.com/job/-/-/599/74019674912
# 29     https://jobs.intel.com/job/-/-/599/74019678416
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#                                                 title  \
# 0                      Construction Estimating Intern
# 1   Tax Internship (January 2025 - April 2025) - O...
# 2                               Data Scientist Intern
# 3            Sector Data Associate – 2025 Intern (US)
# 4             Finance & Accounting – 2025 Intern (US)
# 5                Software Engineer – 2025 Intern (US)
# 6       Internship: Event Support Staff - Los Angeles
# 7                                 Social Media Intern
# 8                              Human Resources Intern
# 9                                    WORTH Internship
# 10  Software Engineer Intern (Data Platform - Big ...
# 11             72 and Sunny Internship Program in USA
# 12       Protégé Agent/Paid Internship - West Wichita
# 13                       Summer Intern - Broadcasting
# 14                         Summer 2025 Intern - Sales
# 15           Intern - Planning Engineer - Summer 2025
# 16                              Corporate FP&A Intern
# 17                                     Student Intern
# 18                            Garden Education Intern
# 19                   Student Intern - Human Resources
# 20                    Heavy Equipment Mechanic Intern
# 21             Undergraduate Summer Program (Pre Law)
# 22              Product Design Intern (Undergraduate)
# 23                              2025 Summer QC Intern
# 24              2025 Summer Intern: Planning Engineer
# 25                                 Legislative Intern
# 26               Construction Winter Intern (3 Weeks)
# 27    University Relations - Reporting Analyst Intern
# 28                Graduate Intern - Software Engineer
# 29                     Power Delivery Research Intern
# 30                                      Safety Intern
# 31          Intern Summer (Engineering) - Emporia, KS
# 32                                  Intern Pharmacist
# 33  Finance Intern/ Accounting Intern/ Recent Grad...
# 34                        Equipment Engineer - Intern
# 35                     Intern (Transmission Services)
# 36                                       Sales Intern
# 37   Marketing Specialist Intern (Sales & HR Support)
# 38                      Intern Engineer - Integration
# 39   Entry Level Special Needs Associate ( 8 am-2 pm)
#
#                                               company  \
# 0                           7B Building & Development
# 1                                     DSB Rock Island
# 2                                       Jabil Circuit
# 3                         Citadel Enterprise Americas
# 4                         Citadel Enterprise Americas
# 5                         Citadel Enterprise Americas
# 6                                        THE HOLY ART
# 7                              Passages International
# 8                 Northstar Behavioral Health Network
# 9               Arukah Institute of Healing, NFP INC.
# 10                                             TikTok
# 11                                         72andSunny
# 12                   Farmers Insurance  - District 72
# 13                                       Usa Baseball
# 14                                  Lotus Sales Group
# 15                                              Lumen
# 16                              LP Building Solutions
# 17                                                SLB
# 18                                   Hawthorne Valley
# 19                                                SLB
# 20                                 Kiewit Corporation
# 21  Fifteenth Judicial Circuit - Court Administration
# 22                                          HashiCorp
# 23                               Granite Construction
# 24                                           Spectrum
# 25                                  University Health
# 26                              AvalonBay Communities
# 27                    Health Care Service Corporation
# 28                                  Intel Corporation
# 29                                  Intel Corporation
# 30                                           Rosendin
# 31                               Simmons Pet Food Inc
# 32                                          Rx relief
# 33                                          BCForward
# 34                                           AppleOne
# 35                                              BHEGT
# 36                               The Chefs' Warehouse
# 37                                Recruiter Aerospace
# 38                   GENERAL DYNAMICS MISSION SYSTEMS
# 39                                         All's Well
#
#                        location date_posted                        job_type  \
# 0                   Lubbock, TX  2024-12-06                             NaN
# 1   Mendota Heights, Dakota, MN  2024-12-06                             NaN
# 2                           NaN  2024-12-06                             NaN
# 3                  New York, NY  2024-12-05                             NaN
# 4                  New York, NY  2024-12-05                             NaN
# 5                   Chicago, IL  2024-12-05                             NaN
# 6                California, KY  2024-12-04                             NaN
# 7               Albuquerque, NM  2024-12-04                             NaN
# 8              Fergus Falls, MN  2024-12-04                             NaN
# 9                 Princeton, IL  2024-12-04                             NaN
# 10                  Seattle, WA  2024-12-05                      internship
# 11                  Oakland, CA  2024-12-04                      internship
# 12                  Wichita, KS  2024-12-03                      internship
# 13                     Cary, NC  2024-12-01                             NaN
# 14                 Thornton, CO  2024-11-30                      internship
# 15               Springdale, AR  2024-11-21                      internship
# 16                Nashville, TN  2024-11-20                      internship
# 17                Cambridge, MA  2024-11-19            fulltime, internship
# 18                    Ghent, NY  2024-11-18                      internship
# 19                 Florence, SC  2024-11-12  fulltime, internship, contract
# 20              Quemado, TX, US  2024-12-06                      internship
# 21      West Palm Beach, FL, US  2024-12-06                        fulltime
# 22                           US  2024-12-06                      internship
# 23               Yakima, WA, US  2024-12-06                        fulltime
# 24               Austin, TX, US  2024-12-06            fulltime, internship
# 25          San Antonio, TX, US  2024-12-05                      internship
# 26             Roseland, NJ, US  2024-12-05                      internship
# 27              Chicago, IL, US  2024-12-05                        fulltime
# 28        Bernardsville, NJ, US  2024-12-04                        fulltime
# 29            Hillsboro, OR, US  2024-12-04                        fulltime
# 30            Sterling, VA, USA  2024-12-06                        fulltime
# 31                Olpe, KS, USA  2024-12-05                             NaN
# 32              Orange, CA, USA  2024-12-05                        fulltime
# 33         Jersey City, NJ, USA  2024-12-05                        contract
# 34          Rocky Hill, CT, USA  2024-12-05                             NaN
# 35            Richmond, VA, USA  2024-12-05                             NaN
# 36         New Bedford, MA, USA  2024-12-05                             NaN
# 37             Bothell, WA, USA  2024-12-05                        parttime
# 38            Manassas, VA, USA  2024-12-04                             NaN
# 39            San Jose, CA, USA  2024-12-03                             NaN
#
#    salary_source  ...                  emails  \
# 0    direct_data  ...                     NaN
# 1    direct_data  ...                     NaN
# 2    direct_data  ...   _Accessible@Jabil.com
# 3            NaN  ...                     NaN
# 4    direct_data  ...                     NaN
# 5            NaN  ...                     NaN
# 6            NaN  ...                     NaN
# 7    direct_data  ...                     NaN
# 8    direct_data  ...                     NaN
# 9    direct_data  ...                     NaN
# 10           NaN  ...                     NaN
# 11           NaN  ...                     NaN
# 12           NaN  ...                     NaN
# 13           NaN  ...                     NaN
# 14   description  ...                     NaN
# 15           NaN  ...                     NaN
# 16           NaN  ...                     NaN
# 17           NaN  ...                     NaN
# 18           NaN  ...                     NaN
# 19           NaN  ...                     NaN
# 20   direct_data  ...                     NaN
# 21   direct_data  ...                     NaN
# 22   direct_data  ...  benefits@hashicorp.com
# 23   direct_data  ...                     NaN
# 24           NaN  ...                     NaN
# 25           NaN  ...                     NaN
# 26   direct_data  ...                     NaN
# 27   direct_data  ...                     NaN
# 28   direct_data  ...                     NaN
# 29   direct_data  ...                     NaN
# 30           NaN  ...                     NaN
# 31           NaN  ...                     NaN
# 32   direct_data  ...                     NaN
# 33   direct_data  ...                     NaN
# 34   direct_data  ...                     NaN
# 35           NaN  ...                     NaN
# 36           NaN  ...                     NaN
# 37   direct_data  ...                     NaN
# 38           NaN  ...                     NaN
# 39   direct_data  ...                     NaN
#
#                                           description  company_industry  \
# 0   We are looking for an enthusiastic Constructio...               NaN
# 1   **Tax Internship** \| January 2025 – April 202...               NaN
# 2   At Jabil we strive to make ANYTHING POSSIBLE a...               NaN
# 3   **Job Description**\n-------------------\n\n\n...               NaN
# 4   **Job Description**\n-------------------\n\n\n...               NaN
# 5   **Job Description**\n-------------------\n\n\n...               NaN
# 6   Job review: Internship\n\nDates: 8 \- 10 March...               NaN
# 7   **Position Summary:**\n\nSymphony Handmade See...               NaN
# 8   Description:\nHuman Resources Intern Job Dutie...               NaN
# 9   **Job Summary**  \nCome join the WORTH team fo...               NaN
# 10  Responsibilities\n\nTikTok is the leading dest...               NaN
# 11  Are you passionate about the creative industry...               NaN
# 12  Job Description\n\nWe are seeking a highly mot...               NaN
# 13  As the Broadcasting Intern, you will report to...               NaN
# 14  At Lotus, one of our core values is personal g...               NaN
# 15  About Lumen\n\nLumen connects the world. We ar...               NaN
# 16  Louisiana-Pacific Corporation (LP Building Sol...               NaN
# 17  The Student Intern is responsible for gaining ...               NaN
# 18  Join the Place Based Learning Center at Hawtho...               NaN
# 19  Student Intern - Human Resources\n\nThe Studen...               NaN
# 20  **Requisition ID: 165224**\n\n\n**Position Sum...               NaN
# 21  **How To Apply:**\n\nhttps://www.governmentjob...               NaN
# 22  **About the team**\n------------------\n\n\n\n...               NaN
# 23  Building a career at Granite may be the most v...               NaN
# 24  **At a Glance*** You’re a motivated rising sen...               NaN
# 25  **POSITION SUMMARY/RESPONSIBILITIES**  \n\nCar...       Health Care
# 26  **Overview**\nAvalonBay Communities, Inc., an ...               NaN
# 27  At HCSC, our employees are the cornerstone of ...       Health Care
# 28  **Job Description**\n-------------------\n\n  ...               NaN
# 29  **Job Description**\n-------------------\n\n  ...               NaN
# 30  Whether you're a recent grad or a seasoned pro...               NaN
# 31  As part of Simmons Foods, interns have the opp...               NaN
# 32  Job description\n\n**Intern Pharmacist**\n\n**...               NaN
# 33  **Job Title: Ops Specialist \- Payment Proc. \...               NaN
# 34  Location: Rocky Hill, CT 06067  \n Schedule: M...               NaN
# 35  BHE GT\&S has an exciting summer internship op...               NaN
# 36  **About The Chefs' Warehouse**  \nThe Chefs' W...               NaN
# 37  Keltia Design Inc. is a well\-established loca...               NaN
# 38  GDMS has an immediate opening for an Engineeri...               NaN
# 39  PURPOSE OF DIRECT SERVICE PROFESSIONAL (DSP) I...               NaN
#
#                                           company_url  \
# 0   https://www.glassdoor.com/Overview/W-EI_IE3771...
# 1   https://www.glassdoor.com/Overview/W-EI_IE1685...
# 2   https://www.glassdoor.com/Overview/W-EI_IE2330...
# 3   https://www.glassdoor.com/Overview/W-EI_IE1493...
# 4   https://www.glassdoor.com/Overview/W-EI_IE1493...
# 5   https://www.glassdoor.com/Overview/W-EI_IE1493...
# 6                                                 NaN
# 7                                                 NaN
# 8   https://www.glassdoor.com/Overview/W-EI_IE2207...
# 9   https://www.glassdoor.com/Overview/W-EI_IE1027...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  https://www.indeed.com/cmp/Kiewit-Corporation-...
# 21  https://www.indeed.com/cmp/Fifteenth-Judicial-...
# 22               https://www.indeed.com/cmp/Hashicorp
# 23  https://www.indeed.com/cmp/Granite-Constructio...
# 24              https://www.indeed.com/cmp/Spectrum-1
# 25     https://www.indeed.com/cmp/University-Health-3
# 26   https://www.indeed.com/cmp/Avalonbay-Communities
# 27  https://www.indeed.com/cmp/Health-Care-Service...
# 28       https://www.indeed.com/cmp/Intel-Corporation
# 29       https://www.indeed.com/cmp/Intel-Corporation
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#                                          company_logo  \
# 0   https://media.glassdoor.com/sql/3771123/7b-bui...
# 1   https://media.glassdoor.com/sql/1685046/ds-b-s...
# 2   https://media.glassdoor.com/sql/2330/jabil-squ...
# 3   https://media.glassdoor.com/sql/14937/citadel-...
# 4   https://media.glassdoor.com/sql/14937/citadel-...
# 5   https://media.glassdoor.com/sql/14937/citadel-...
# 6                                                 NaN
# 7                                                 NaN
# 8   https://media.glassdoor.com/sql/2207604/norths...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 21                                                NaN
# 22  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 23  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 24  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 25  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 26  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 27  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 28  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 29  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#                       company_url_direct  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
# 19                                   NaN
# 20                 http://www.kiewit.com
# 21               http://15thcircuit.com/
# 22             https://www.hashicorp.com
# 23  https://www.graniteconstruction.com/
# 24              http://jobs.spectrum.com
# 25     https://www.universityhealth.com/
# 26     https://www.avaloncommunities.com
# 27    http://hcsc.com/careers/index.html
# 28               https://jobs.intel.com/
# 29               https://jobs.intel.com/
# 30                                   NaN
# 31                                   NaN
# 32                                   NaN
# 33                                   NaN
# 34                                   NaN
# 35                                   NaN
# 36                                   NaN
# 37                                   NaN
# 38                                   NaN
# 39                                   NaN
#
#                                  company_addresses company_num_employees  \
# 0                                              NaN                   NaN
# 1                                              NaN                   NaN
# 2                                              NaN                   NaN
# 3                                              NaN                   NaN
# 4                                              NaN                   NaN
# 5                                              NaN                   NaN
# 6                                              NaN                   NaN
# 7                                              NaN                   NaN
# 8                                              NaN                   NaN
# 9                                              NaN                   NaN
# 10                                             NaN                   NaN
# 11                                             NaN                   NaN
# 12                                             NaN                   NaN
# 13                                             NaN                   NaN
# 14                                             NaN                   NaN
# 15                                             NaN                   NaN
# 16                                             NaN                   NaN
# 17                                             NaN                   NaN
# 18                                             NaN                   NaN
# 19                                             NaN                   NaN
# 20                                       Omaha, NE               10,000+
# 21                                             NaN                   NaN
# 22                                   San Francisco             51 to 200
# 23                                 Watsonville, CA       5,001 to 10,000
# 24                                    Stamford, CT               10,000+
# 25  4502 Medical Drive\r\nSan Antonio, Texas 78229               10,000+
# 26                                   Arlington, VA        1,001 to 5,000
# 27                                             NaN                   NaN
# 28                                 Santa Clara, CA               10,000+
# 29                                 Santa Clara, CA               10,000+
# 30                                             NaN                   NaN
# 31                                             NaN                   NaN
# 32                                             NaN                   NaN
# 33                                             NaN                   NaN
# 34                                             NaN                   NaN
# 35                                             NaN                   NaN
# 36                                             NaN                   NaN
# 37                                             NaN                   NaN
# 38                                             NaN                   NaN
# 39                                             NaN                   NaN
#
#          company_revenue                                company_description
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# 5                    NaN                                                NaN
# 6                    NaN                                                NaN
# 7                    NaN                                                NaN
# 8                    NaN                                                NaN
# 9                    NaN                                                NaN
# 10                   NaN                                                NaN
# 11                   NaN                                                NaN
# 12                   NaN                                                NaN
# 13                   NaN                                                NaN
# 14                   NaN                                                NaN
# 15                   NaN                                                NaN
# 16                   NaN                                                NaN
# 17                   NaN                                                NaN
# 18                   NaN                                                NaN
# 19                   NaN                                                NaN
# 20  more than $10B (USD)  Kiewit is one of North America's largest and m...
# 21                   NaN                                                NaN
# 22                   NaN                                                NaN
# 23      $1B to $5B (USD)  Granite is an industry leader in safety and an...
# 24  more than $10B (USD)  Spectrum is the nation’s fastest-growing TV, I...
# 25                   NaN
# 26      $1B to $5B (USD)  We develop, build, own and operate a wide arra...
# 27                   NaN  Health Care Service Corporation (HCSC) is the ...
# 28  more than $10B (USD)  Intel put the Silicon in Silicon Valley, and t...
# 29  more than $10B (USD)  Intel put the Silicon in Silicon Valley, and t...
# 30                   NaN                                                NaN
# 31                   NaN                                                NaN
# 32                   NaN                                                NaN
# 33                   NaN                                                NaN
# 34                   NaN                                                NaN
# 35                   NaN                                                NaN
# 36                   NaN                                                NaN
# 37                   NaN                                                NaN
# 38                   NaN                                                NaN
# 39                   NaN                                                NaN
#
# [40 rows x 28 columns]

# %% [markdown]
# ### OpenWebNinja API

# %%
def OpenWebNinjaAPI(search_term,location,country,n):
  import requests
  import pandas as pd
  import json

  url = "https://jsearch.p.rapidapi.com/search"

  querystring = {"query": search_term+" jobs in"+location,"page":"1","num_pages":n,"country":country,"date_posted":"all"}

  headers = {
	"x-rapidapi-key": "cdad6700bdmsh5ac106aa01f9ea7p104d83jsn15813f7690aa",
	"x-rapidapi-host": "jsearch.p.rapidapi.com"
}

  response = requests.get(url, headers=headers, params=querystring)

  # Parse the JSON response
  data = response.json()



  # Extract the job listings from the 'data' key
  job_listings = data.get('data', [])

  # Create a DataFrame from the job listings
  df = pd.DataFrame(job_listings)

  return df

# %% [markdown]
# ### Google Maps API
# For getting the heatmap of where the jobs are located

# %%
def GMapsAPI(location):
  gmaps = googlemaps.Client(key='AIzaSyAkhVVl0ombrXrKoLIOQmhp3btAJ6alyF4')

  geocode_result = gmaps.geocode(location)
  if geocode_result:
        lat = geocode_result[0]['geometry']['location']['lat']
        lng = geocode_result[0]['geometry']['location']['lng']
        return lat, lng
  return None, None

# %% [markdown]
# ### Data Cleaning
# For cleaning up nulls in the dataset

# %%
import pandas as pd

def data_merger(jobspy, open_web_ninja):
    new_columns = ['job_title', 'job_employment_type', 'employer_name', 'job_city', 'job_state', 'job_posted_at_datetime_utc', 'employer_website', 'job_apply_link']

    # Process open_web_ninja data
    new_data = open_web_ninja[new_columns]

    # Process jobspy data
    new_data_1 = pd.DataFrame()
    new_data_1['job_title'] = jobspy['title']
    new_data_1['job_employment_type'] = jobspy['job_type']
    new_data_1['employer_name'] = jobspy['company']
    new_data_1['job_city'] = jobspy['location'].apply(lambda x: x.split(',')[0].strip() if isinstance(x, str) and ',' in x else x)
    new_data_1['job_state'] = jobspy['location'].apply(lambda x: x.split(',')[1].strip() if isinstance(x, str) and ',' in x else '')
    new_data_1['job_posted_at_datetime_utc'] = jobspy['date_posted']
    new_data_1['employer_website'] = jobspy['job_url_direct']
    new_data_1['job_apply_link'] = jobspy['job_url']

    # Concatenate the two DataFrames
    combined_data = pd.concat([new_data, new_data_1], ignore_index=True)

    return combined_data

def data_cleaning(df):
    # Fill missing datetime values with current date
        df['job_posted_at_datetime_utc'].fillna('2024-12-03T00:00:00.000Z', inplace=True)
        # Replace NaN values with None for proper JSON serialization
        df = df.where(pd.notnull(df), None)
        return df

# %% [markdown]
# ### HTMX and Flask
# Functions related to communication between the server

# %%
from re import search
from flask import Flask, request, jsonify, render_template
import pandas as pd
from pyngrok import ngrok
import os
from flask_cors import CORS
app = Flask(__name__, template_folder='/content/templates')
app.config.update(
    MAIL_SERVER='smtp.gmail.com',
    MAIL_PORT=587,
    MAIL_USE_TLS=True,
    MAIL_USERNAME="scannjobright@gmail.com",
    MAIL_PASSWORD="czvr nwyz ophy accm",
    MAIL_DEFAULT_SENDER="scannjobright@gmail.com",
    TESTING=False,
    MAIL_SUPPRESS_SEND=False
)
mail = Mail(app)

CORS(app)
port = 5000

state='Illinois'
location=''
search_term=''
empty=[]
results_data=pd.DataFrame(empty);

@app.route('/favicon.ico')
def favicon():
    # Provide the path to the favicon.ico file
    return send_from_directory(
        directory='static',  # Replace with your static folder path
        filename='favicon.ico',
        mimetype='image/vnd.microsoft.icon'
    )

# Global variable to cache jobs data
@app.route("/", methods=["GET", "POST"])
def index():
    if request.method == "POST":
        try:
            search_term = request.form.get("search_term")
            location = request.form.get("location")
            employment_type = request.form.get("employment_type")
            state = request.form.get("state")

            # Perform the search using the received parameters
            jobs = JobSpyAPI(search_term, location, "100","USA")
            open_jobs = OpenWebNinjaAPI(search_term, location, "USA", "10")


            results_data = data_merger(jobs, open_jobs)

            if employment_type:
                results_data = results_data[results_data['job_employment_type'] == employment_type]
            if state:
                results_data = results_data[results_data['job_state'] == state]

            results_data = data_cleaning(results_data)
            print(results_data)
            results_data.to_csv("open_web_ninja.csv", index=False)

            return jsonify(results_data.to_dict(orient="records"))

            page = request.args.get('page', 1, type=int)  # Default to page 1
            per_page = 10  # Number of items per page

        except Exception as e:
            if not all([request.form.get("search_term"), request.form.get("location")]):
                return jsonify({"error": "Missing required parameters"}), 400


    return render_template("index5.html")



@app.route("/get-jobs", methods=['GET'])
def get_jobs():
    try:
        jobs_df = pd.read_csv("open_web_ninja.csv")
        jobs_df = data_cleaning(jobs_df)

        # Apply filters from query parameters
        search_term = request.args.get("search_term")
        print(search_term)
        location = request.args.get("location")
        print(location)
        employment_type = request.args.get("employment_type")
        state = request.args.get("state")

        if search_term:
            jobs_df = jobs_df[jobs_df['job_title'].str.contains(search_term, case=False)]
        if location:
            jobs_df = jobs_df[jobs_df['job_city'].str.contains(location, case=False) | jobs_df['job_state'].str.contains(location, case=False)]
        if employment_type:
            jobs_df = jobs_df[jobs_df['job_employment_type'] == employment_type]
        if state:
            jobs_df = jobs_df[jobs_df['job_state'] == state]
        jobs_data = jobs_df.to_dict(orient="records")
        return jsonify(jobs_data)
    except FileNotFoundError:
        return jsonify({"error": "CSV file not found"}), 404
    except Exception as e:
        return jsonify({"error": str(e)}), 500


@app.route("/get-states")
def get_states():
    us_states = [
        "Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado",
        "Connecticut", "Delaware", "Florida", "Georgia", "Hawaii", "Idaho",
        "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana",
        "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota",
        "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada",
        "New Hampshire", "New Jersey", "New Mexico", "New York",
        "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon",
        "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota",
        "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington",
        "West Virginia", "Wisconsin", "Wyoming"
    ]
    return jsonify({'states': us_states})


@app.route('/filter-state', methods=['GET', 'POST'])
def filter_state():
    state = request.form.get('state', '') if request.method == 'POST' else request.args.get('state', '')
    try:
        jobs_df = pd.read_csv("open_web_ninja.csv")
        jobs_df = data_cleaning(jobs_df)
        print(jobs_df)
        if state:
            filtered_jobs = jobs_df[jobs_df['job_state'] == state].to_dict(orient='records')
        else:
            filtered_jobs = jobs_df.to_dict('records')
        return jsonify(filtered_jobs)
    except FileNotFoundError:
        return jsonify({"error": "No jobs found"}), 404


@app.route('/geocode')
def geocode():
    location = request.args.get('location')
    if location:
        lat, lng = GMapsAPI(location)
        if lat and lng:
            return jsonify({'lat': lat, 'lng': lng})
    return jsonify({'error': 'Location not found'}), 404


@app.route("/save-email", methods=['POST'])
def send_email_subscription():
    try:
        email = request.get_json(force=True).get('email')
        if not email:
            return jsonify({"error": "Email is required"}), 400

        msg = Message(
            subject="Job Updates Subscription",
            sender="scannjobright@gmail.com",
            recipients=[email],
            body="Thank you for subscribing to job updates!"
        )

        try:
            with open("open_web_ninja.csv", "rb") as fp:
                msg.attach("open_web_ninja.csv", "text/csv", fp.read())
        except FileNotFoundError:
            app.logger.warning("CSV file not found")

        mail.send(msg)
        return jsonify({"success": True})

    except Exception as e:
        app.logger.error(f"Email error: {str(e)}")
        return jsonify({"error": "Error sending email. Please try again."}), 500


if __name__ == "__main__":
    # Install pyngrok
    os.system('pip install pyngrok')

    # Set up ngrok
    ngrok.set_auth_token("2piUX4ZA1w9aqufFUk8fNF49MC7_4oJPUp4vXv8nVMhxuYWU3")
    public_url = ngrok.connect(port)
    print(f" * ngrok tunnel \"{public_url}\" -> \"http://127.0.0.1:{port}\"")

    # Run the Flask app
    app.run(port=port)
# Out:
#  * ngrok tunnel "NgrokTunnel: "https://baaa-35-197-92-154.ngrok-free.app" -> "http://localhost:5000"" -> "http://127.0.0.1:5000"
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:15] "GET / HTTP/1.1" 200 -
# <ipython-input-23-3fcf4c597cb2>:27: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['job_posted_at_datetime_utc'].fillna('2024-12-03T00:00:00.000Z', inplace=True)
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /get-jobs HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /get-states HTTP/1.1" 200 -
# None
# None
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Los%20Angeles,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=West%20Hollywood,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Marina%20Del%20Rey,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Hermosa%20Beach,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=El%20Segundo,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Beverly%20Hills,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Beverly%20Hills,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Rancho%20Dominguez,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Glendale,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Malibu,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Stanton,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Culver%20City,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Ana,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Orange,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Irvine,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Los%20Angeles,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Los%20Angeles,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=West%20Hollywood,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Los%20Angeles,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:16] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Santa%20Monica,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=El%20Segundo,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /geocode?location=Los%20Angeles,%20CA HTTP/1.1" 200 -
# ERROR:__main__:Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/flask/app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.10/dist-packages/flask/app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.10/dist-packages/flask_cors/extension.py", line 194, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "/usr/local/lib/python3.10/dist-packages/flask/app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.10/dist-packages/flask/app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "<ipython-input-40-ef11f6cc1b94>", line 32, in favicon
#     return send_from_directory(
# NameError: name 'send_from_directory' is not defined
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:17] "GET /favicon.ico HTTP/1.1" 500 -
# 2024-12-06 15:10:28,473 - INFO - JobSpy:Indeed - search page: 1 / 1
# 2024-12-06 15:10:28,477 - INFO - JobSpy:LinkedIn - search page: 1 / 1
# 2024-12-06 15:10:28,662 - INFO - JobSpy:ZipRecruiter - search page: 1 / 1
# 2024-12-06 15:10:29,030 - WARNING - JobSpy:Google - initial cursor not found, try changing your query or there was at most 10 results
# 2024-12-06 15:10:29,047 - INFO - JobSpy:Google - finished scraping
# 2024-12-06 15:10:29,319 - INFO - JobSpy:ZipRecruiter - finished scraping
# 2024-12-06 15:10:29,435 - INFO - JobSpy:Linkedin - finished scraping
# 2024-12-06 15:10:29,656 - INFO - JobSpy:Glassdoor - search page: 1 / 1
# 2024-12-06 15:10:29,682 - INFO - JobSpy:Indeed - finished scraping
# 2024-12-06 15:10:30,925 - INFO - JobSpy:Glassdoor - finished scraping
# <ipython-input-23-3fcf4c597cb2>:27: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['job_posted_at_datetime_utc'].fillna('2024-12-03T00:00:00.000Z', inplace=True)
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:41] "POST / HTTP/1.1" 200 -
#                                              job_title job_employment_type  \
# 0         AI Innovation Intern – People & Culture (HR)           Full–time
# 1                Field Applications Engineering Intern          Internship
# 2    Software Engineer Intern (Data Platform - Big ...          Internship
# 3           Internship - Summer 2025 - San Jose Office          Internship
# 4                   2025 Intern - Knowledge Management           Full–time
# ..                                                 ...                 ...
# 134   Entry Level Special Needs Associate ( 8 am-2 pm)                None
# 135  Undergraduate Intern, Computational and Mathem...                None
# 136  Silicon Interposer Design Flow Development Intern                None
# 137  Machine Learning Research Intern, Frontier Rea...                None
# 138           VC Internship (English/Korean Bilingual)            fulltime
#
#             employer_name       job_city   job_state  \
# 0                 Zscaler       San Jose  California
# 1                 Renesas       San Jose  California
# 2                  TikTok       San Jose  California
# 3    Skyline Construction       San Jose  California
# 4                   Adobe       San Jose  California
# ..                    ...            ...         ...
# 134            All's Well       San Jose          CA
# 135     SRI International     Menlo Park          CA
# 136                 Rivos    Santa Clara          CA
# 137        Scale AI, Inc.  San Francisco          CA
# 138       Naver U Hub Inc   Redwood City          CA
#
#     job_posted_at_datetime_utc                       employer_website  \
# 0     2024-12-04T00:00:00.000Z                https://www.zscaler.com
# 1     2024-12-05T20:00:00.000Z                https://www.renesas.com
# 2     2024-12-05T00:00:00.000Z                 https://www.tiktok.com
# 3     2024-12-04T00:00:00.000Z  https://www.skylineconstruction.build
# 4     2024-12-03T00:00:00.000Z                  https://www.adobe.com
# ..                         ...                                    ...
# 134                 2024-12-03                                   None
# 135                 2024-12-03                                   None
# 136                 2024-12-03                                   None
# 137                 2024-12-03                                   None
# 138                 2024-12-03                                   None
#
#                                         job_apply_link
# 0    https://www.linkedin.com/jobs/view/ai-innovati...
# 1    https://jobs.renesas.com/job/field-application...
# 2    https://www.linkedin.com/jobs/view/software-en...
# 3    https://www.linkedin.com/jobs/view/internship-...
# 4    https://careers.adobe.com/us/en/job/R148747/20...
# ..                                                 ...
# 134  https://www.ziprecruiter.com/jobs//j?lvk=ziJku...
# 135  https://www.ziprecruiter.com/jobs//j?lvk=l_4nF...
# 136  https://www.ziprecruiter.com/jobs//j?lvk=Y7-Yk...
# 137  https://www.ziprecruiter.com/jobs//j?lvk=iuJVb...
# 138  https://www.ziprecruiter.com/jobs//j?lvk=r3k-4...
#
# [139 rows x 8 columns]
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Washington,%20District%20of%20Columbia HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Palo%20Alto,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=New%20York,%20New%20York HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Livermore,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Foster%20City,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Richmond,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Leandro,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Los%20Gatos,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Francisco,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Santa%20Clara,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Mountain%20View,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Ramon,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Redwood%20City,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Milpitas,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Moraga,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Hollister,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Menlo%20Park,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Newark,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Fremont,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Oakland,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Sunnyvale,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:42] "GET /geocode?location=Menlo%20Park,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Francisco,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=Los%20Gatos,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=Santa%20Clara,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=Santa%20Clara,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=Los%20Gatos,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Francisco,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=Fremont,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=Santa%20Clara,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=Fremont,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=Santa%20Clara,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=Los%20Gatos,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=Palo%20Alto,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Francisco,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=Milpitas,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=Los%20Gatos,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Francisco,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=Palo%20Alto,%20CA HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Dec/2024 15:10:43] "GET /geocode?location=San%20Jose,%20California HTTP/1.1" 200 -
# WARNING:pyngrok.process.ngrok:t=2024-12-06T15:18:23+0000 lvl=warn msg="Stopping forwarder" name=http-5000-e11c09b2-8ca1-4dce-bb74-3d276e536cb4 acceptErr="failed to accept connection: Listener closed"
# WARNING:pyngrok.process.ngrok:t=2024-12-06T15:18:23+0000 lvl=warn msg="Error restarting forwarder" name=http-5000-e11c09b2-8ca1-4dce-bb74-3d276e536cb4 err="failed to start tunnel: session closed"
